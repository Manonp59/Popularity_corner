# %%
import pandas as pd 

df = pd.read_csv('/home/apprenant/DevIA/Popularity_corner/popularity_corner/data_movies.csv')

# %%
df.shape
# Out:
# (9093, 17)

# %%
df = df.loc[df['box_office_title'] == 'Box Office France']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df = df.loc[df['box_office_title'] == ['Box Office France']]
#
# File ~/miniconda3/envs/scrap-env/lib/python3.11/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/miniconda3/envs/scrap-env/lib/python3.11/site-packages/pandas/core/arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File ~/miniconda3/envs/scrap-env/lib/python3.11/site-packages/pandas/core/series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File ~/miniconda3/envs/scrap-env/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:264, in comparison_op(left, right, op)
#     259 if isinstance(rvalues, (np.ndarray, ABCExtensionArray)):
#     260     # TODO: make this treatment consistent across ops and classes.
#     261     #  We are not catching all listlikes here (e.g. frozenset, tuple)
#     262     #  The ambiguous case is object-dtype.  See GH#27803
#     263     if len(lvalues) != len(rvalues):
# --> 264         raise ValueError(
#     265             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     266         )
#     268 if should_extension_dispatch(lvalues, rvalues) or (
#     269     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     270     and not is_object_dtype(lvalues.dtype)
#     271 ):
#     272     # Call the method on lvalues
#     273     res_values = op(lvalues, rvalues)
#
# ValueError: ('Lengths must match to compare', (9093,), (1,))

# %%
df.shape
# Out:
# (0, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8465 entries, 0 to 9308
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  8465 non-null   object
#  1   release_date           8343 non-null   object
#  2   genre                  8460 non-null   object
#  3   duration               8465 non-null   object
#  4   director               8465 non-null   object
#  5   producers              8254 non-null   object
#  6   cast                   8355 non-null   object
#  7   age_limit              2331 non-null   object
#  8   nationality            8465 non-null   object
#  9   distributor            8465 non-null   object
#  10  box_office_title       8465 non-null   object
#  11  box_office_first_week  8465 non-null   int64
#  12  press_eval             8448 non-null   object
#  13  viewers_eval           8441 non-null   object
#  14  views                  8331 non-null   float64
# dtypes: float64(1), int64(1), object(13)
# memory usage: 1.0+ MB

# %%
df = df.drop('age_limit', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8465 entries, 0 to 9308
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  8465 non-null   object
#  1   release_date           8343 non-null   object
#  2   genre                  8460 non-null   object
#  3   duration               8465 non-null   object
#  4   director               8465 non-null   object
#  5   producers              8254 non-null   object
#  6   cast                   8355 non-null   object
#  7   nationality            8465 non-null   object
#  8   distributor            8465 non-null   object
#  9   box_office_title       8465 non-null   object
#  10  box_office_first_week  8465 non-null   int64
#  11  press_eval             8448 non-null   object
#  12  viewers_eval           8441 non-null   object
#  13  views                  8331 non-null   float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 992.0+ KB

# %%
df = df.dropna(subset=['producers', 'release_date','cast','views','press_eval','viewers_eval'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7939 entries, 0 to 9113
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7939 non-null   object
#  1   release_date           7939 non-null   object
#  2   genre                  7939 non-null   object
#  3   duration               7939 non-null   object
#  4   director               7939 non-null   object
#  5   producers              7939 non-null   object
#  6   cast                   7939 non-null   object
#  7   nationality            7939 non-null   object
#  8   distributor            7939 non-null   object
#  9   box_office_title       7939 non-null   object
#  10  box_office_first_week  7939 non-null   int64
#  11  press_eval             7939 non-null   object
#  12  viewers_eval           7939 non-null   object
#  13  views                  7939 non-null   float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 930.4+ KB

# %%
df['title'] = df['title'].str.lower()

# %%
df.drop_duplicates()
# Out:
#                                title     release_date  \
# 0     guardians of the galaxy vol. 3       3 mai 2023
# 1                       sexygénaires     14 juin 2023
# 2                    pornomelancolía     21 juin 2023
# 4                     sick of myself      31 mai 2023
# 5                    la syndicaliste      1 mars 2023
# ...                              ...              ...
# 9105             wszystko, co kocham    20 avril 2011
# 9108         shapito show - partie 2  16 juillet 2014
# 9110           le murmure des ruines     26 juin 2013
# 9112                           bends  15 juillet 2015
# 9113                 not in tel-aviv      5 juin 2013
#
#                                      genre  duration             director  \
# 0     Action, Fantastique, Science fiction  2h 30min           James Gunn
# 1                                  Comédie  1h 20min          Robin Sykes
# 2                                    Drame  1h 34min    Manuel Abramovich
# 4                       Comédie dramatique  1h 37min    Kristoffer Borgli
# 5                          Thriller, Drame  2h 01min     Jean-Paul Salomé
# ...                                    ...       ...                  ...
# 9105               Drame, Musical, Comédie  1h 35min        Jacek Borcuch
# 9108                      Comédie, Musical  1h 51min         Sergei Loban
# 9110                                 Drame  1h 33min  Liliane de Kermadec
# 9112                                 Drame  1h 32min            Flora Lau
# 9113              Comédie, Policier, Drame  1h 22min          Nony Geffen
#
#                               producers  \
# 0                            James Gunn
# 1        Antoine Raimbault, Robin Sykes
# 2     Manuel Abramovich, Fernando Krapp
# 4                     Kristoffer Borgli
# 5     Fadette Drouard, Jean-Paul Salomé
# ...                                 ...
# 9105                      Jacek Borcuch
# 9108                    Marina Potapova
# 9110                Liliane de Kermadec
# 9112              Carina Lau, Flora Lau
# 9113                        Nony Geffen
#
#                                                    cast nationality  \
# 0               Chris Pratt, Zoe Saldana, Dave Bautista      U.S.A.
# 1        Thierry Lhermitte, Patrick Timsit, Marie Bunel      France
# 2                     Lalo Santos,  Diablo, Brandon Ley   Argentine
# 4     Kristine Kujath Thorp, Eirik Sæther, Fanny Vaager     Norvège
# 5        Isabelle Huppert, Grégory Gadebois, Yvan Attal      France
# ...                                                 ...         ...
# 9105  Mateusz Kosciukiewicz, Olga Frycz, Jakub Gierszal     Pologne
# 9108   Piotr Mamonov, Stas Baretskiy, Aleksey Podolskiy      Russie
# 9110  Ruben Verdyan, Sarassar Sarayan, Hovhanès Khod...      France
# 9112                    Carina Lau, Kun Chen, Yuan Tian   Hong-Kong
# 9113          Nony Geffen, Romi Aboulafia, Yaara Pelzig      Israël
#
#                          distributor   box_office_title  \
# 0     The Walt Disney Company France  Box Office France
# 1       Apollo Films / Orange Studio  Box Office France
# 2                    Epicentre Films  Box Office France
# 4                             Tandem  Box Office France
# 5                           Le Pacte  Box Office France
# ...                              ...                ...
# 9105   Marc Guidoni / Fodivina Films  Box Office France
# 9108             Damned Distribution  Box Office France
# 9110                     107 entrées  Box Office France
# 9112                 A3 Distribution  Box Office France
# 9113            Arizona Distribution  Box Office France
#
#       box_office_first_week press_eval viewers_eval     views
# 0                   1323124        3,6          4,2  251776.0
# 1                     63084        2,8          2,6   25555.0
# 2                      3611        3,5          2,6    6778.0
# 4                     14638        3,4          3,4   87714.0
# 5                    192422        3,3          3,9  182409.0
# ...                     ...        ...          ...       ...
# 9105                   2016        3,2          3,2   50774.0
# 9108                    172        3,2          3,6   40846.0
# 9110                    152        2,6          3,0     310.0
# 9112                    826        2,9          3,1    5669.0
# 9113                    282        2,6          2,6    3212.0
#
# [7939 rows x 14 columns]

# %%
import dateparser

# Convertir la colonne "date" en objets de type datetime de Pandas
df['release_date'] = df['release_date'].apply(lambda x: dateparser.parse(x).date())

# Créer une nouvelle colonne "année" en extrayant l'année à partir de la colonne "date"
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7939 entries, 0 to 9113
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7939 non-null   object
#  1   release_date           7939 non-null   datetime64[ns]
#  2   genre                  7939 non-null   object
#  3   duration               7939 non-null   object
#  4   director               7939 non-null   object
#  5   producers              7939 non-null   object
#  6   cast                   7939 non-null   object
#  7   nationality            7939 non-null   object
#  8   distributor            7939 non-null   object
#  9   box_office_title       7939 non-null   object
#  10  box_office_first_week  7939 non-null   int64
#  11  press_eval             7939 non-null   object
#  12  viewers_eval           7939 non-null   object
#  13  views                  7939 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(11)
# memory usage: 930.4+ KB

# %%
import requests

def get_id(name, api_key):
    base_url = 'https://api.themoviedb.org/3/search/movie'
    url = f'{base_url}?api_key={api_key}&query={name}'
    response = requests.get(url)
    if response.status_code == 200:
        search_results = response.json()
        if search_results['total_results'] > 0:
            # Prendre le premier résultat de la liste (vous pouvez afficher tous les résultats si nécessaire)
            first_result = search_results['results'][0]
            movie_id = first_result['id']
            return movie_id
        else:
            return f"Aucun résultat trouvé pour '{name}'."
    else:
        return "Erreur lors de la requête API 1 ."

def get_budget(movie_id, api_key):
    base_url = 'https://api.themoviedb.org/3/movie/'
    url = f'{base_url}{movie_id}?api_key={api_key}'

    # Effectuer la requête
    response = requests.get(url)

    # Analyser la réponse JSON
    if response.status_code == 200:
        movie_data = response.json()
        budget = movie_data.get('budget')
        return budget
    else:
        return "Erreur lors de la requête API 2."

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv('API_KEY_BUDGET')

for index, row in df.iterrows():
    title = row['title']
    budget = get_budget(get_id(title, api_key), api_key)
    df.at[index, 'budget'] = budget

# %%
import pandas as pd

df_meteo = pd.read_csv('weekly_average_temperatures.csv')

# %%
import pandas as pd

# Assurez-vous que les colonnes "Start Date" et "End Date" de df_meteo sont au format datetime
df_meteo['Start Date'] = pd.to_datetime(df_meteo['Start Date'])
df_meteo['End Date'] = pd.to_datetime(df_meteo['End Date'])

# Ajouter une colonne "Temperature Moyenne" à df_films
df['Temperature Moyenne'] = None

villes = ['Lille', 'Bordeaux', 'Lyon', 'Paris']
for ville in villes:
    df[ville] = None

# Parcourir chaque date de sortie dans df_films
for index, row in df.iterrows():
    release_date = row['release_date']
    
    # Rechercher la semaine correspondante dans df_meteo
    matching_week = df_meteo[(df_meteo['Start Date'] <= release_date) & (df_meteo['End Date'] >= release_date)]
    
    if not matching_week.empty:
        # Récupérer la température moyenne pour cette semaine
        temperature_moyenne = matching_week.iloc[0]['Moyenne']
        
        # Ajouter la température moyenne à la colonne correspondante dans df_films
        df.at[index, 'Temperature Moyenne'] = temperature_moyenne
        
        for ville in villes:
            temperature_ville = matching_week.iloc[0][ville]
            df.at[index, ville] = temperature_ville

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7939 entries, 0 to 9113
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7939 non-null   object
#  1   release_date           7939 non-null   datetime64[ns]
#  2   genre                  7939 non-null   object
#  3   duration               7939 non-null   object
#  4   director               7939 non-null   object
#  5   producers              7939 non-null   object
#  6   cast                   7939 non-null   object
#  7   nationality            7939 non-null   object
#  8   distributor            7939 non-null   object
#  9   box_office_title       7939 non-null   object
#  10  box_office_first_week  7939 non-null   int64
#  11  press_eval             7939 non-null   object
#  12  viewers_eval           7939 non-null   object
#  13  views                  7939 non-null   float64
#  14  budget                 7939 non-null   object
#  15  Temperature Moyenne    5935 non-null   object
#  16  Lille                  5935 non-null   object
#  17  Bordeaux               5935 non-null   object
#  18  Lyon                   5935 non-null   object
#  19  Paris                  5935 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(17)
# memory usage: 1.5+ MB

# %%
df_sans_meteo = df.drop(['Temperature Moyenne','Lille','Paris','Lyon','Bordeaux'], axis=1)
df_sans_meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7939 entries, 0 to 9113
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7939 non-null   object
#  1   release_date           7939 non-null   datetime64[ns]
#  2   genre                  7939 non-null   object
#  3   duration               7939 non-null   object
#  4   director               7939 non-null   object
#  5   producers              7939 non-null   object
#  6   cast                   7939 non-null   object
#  7   nationality            7939 non-null   object
#  8   distributor            7939 non-null   object
#  9   box_office_title       7939 non-null   object
#  10  box_office_first_week  7939 non-null   int64
#  11  press_eval             7939 non-null   object
#  12  viewers_eval           7939 non-null   object
#  13  views                  7939 non-null   float64
#  14  budget                 7939 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(12)
# memory usage: 1.2+ MB

# %%
df_avec_meteo = df.dropna(subset='Temperature Moyenne')
df_avec_meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5935 entries, 0 to 9113
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  5935 non-null   object
#  1   release_date           5935 non-null   datetime64[ns]
#  2   genre                  5935 non-null   object
#  3   duration               5935 non-null   object
#  4   director               5935 non-null   object
#  5   producers              5935 non-null   object
#  6   cast                   5935 non-null   object
#  7   nationality            5935 non-null   object
#  8   distributor            5935 non-null   object
#  9   box_office_title       5935 non-null   object
#  10  box_office_first_week  5935 non-null   int64
#  11  press_eval             5935 non-null   object
#  12  viewers_eval           5935 non-null   object
#  13  views                  5935 non-null   float64
#  14  budget                 5935 non-null   object
#  15  Temperature Moyenne    5935 non-null   object
#  16  Lille                  5935 non-null   object
#  17  Bordeaux               5935 non-null   object
#  18  Lyon                   5935 non-null   object
#  19  Paris                  5935 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(17)
# memory usage: 973.7+ KB

# %%
df_avec_meteo.to_csv('df_avec_meteo.csv')
df_sans_meteo.to_csv('df_sans_meteo.csv')
