# %%
import pandas as pd 

df = pd.read_csv('df_model_sans_meteo2.csv',index_col=0 )

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['box_office_first_week','genre'],axis=1)
y = df['box_office_first_week']
X_train,X_test, y_train,y_test = train_test_split(X,y, train_size=0.9,shuffle=True, random_state=42)

# %%
X.columns
# Out:
# Index(['duration', 'nationality', 'press_eval', 'viewers_eval', 'views',
#        'budget', 'season', 'is_holiday', 'proportion_stars_actors',
#        'proportion_stars_producers', 'proportion_stars_director',
#        'distributor_avg_frequency', 'genre_action', 'genre_animation',
#        'genre_arts martiaux', 'genre_aventure', 'genre_biopic',
#        'genre_bollywood', 'genre_comédie', 'genre_comédie dramatique',
#        'genre_comédie musicale', 'genre_divers', 'genre_drame',
#        'genre_epouvante-horreur', 'genre_erotique', 'genre_espionnage',
#        'genre_expérimental', 'genre_famille', 'genre_fantastique',
#        'genre_guerre', 'genre_historique', 'genre_judiciaire', 'genre_musical',
#        'genre_policier', 'genre_péplum', 'genre_romance',
#        'genre_science fiction', 'genre_sport event', 'genre_thriller',
#        'genre_western'],
#       dtype='object')

# %%
# Importer les bibliothèques nécessaires
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from catboost import CatBoostRegressor
from sklearn.metrics import r2_score, mean_squared_error
import optuna
from optuna.samplers import TPESampler
import pandas as pd
import numpy as np

# Définir les paramètres du préprocesseur
numerical_features = ['duration', 'press_eval', 'views', 'budget','proportion_stars_actors', 'proportion_stars_producers', 'proportion_stars_director', 'distributor_avg_frequency']
categorical_features = ['nationality', 'season', 'is_holiday']

numerical_transformer = StandardScaler()
categorical_transformer = OneHotEncoder()

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ],
    remainder="passthrough"
)
def objective(trial):
    # Définir les hyperparamètres à optimiser
    params = {
        'iterations': 1000,  # Nombre d'itérations (vous pouvez augmenter cela)
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'depth': trial.suggest_int('depth', 3, 10),
        'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
        'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'thread_count': 4,
        'verbose': False
    }
    
    # Instancier le modèle CatBoostRegressor avec les hyperparamètres spécifiés
    model = CatBoostRegressor(**params, random_state=42)
    

    # Créer le pipeline avec le préprocesseur et le modèle
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('model', model)
    ])

    # Entraîner le modèle
    pipeline.fit(X_train, y_train)

    # Faire des prédictions sur les données de validation
    y_pred = pipeline.predict(X_test)

    # Calculer la métrique d'évaluation (par exemple, le R2 score)
    score = r2_score(y_test, y_pred)

    return score

# Créer l'étude Optuna
sampler = TPESampler(seed=42)  # Make the sampler behave in a deterministic way.
study = optuna.create_study(sampler=sampler, direction='maximize')

# Lancer l'optimisation des hyperparamètres
study.optimize(objective, n_trials=100)

# Obtenir les meilleurs hyperparamètres trouvés
best_params = study.best_params

# Créer le pipeline final avec les meilleurs hyperparamètres
best_model = CatBoostRegressor(**best_params)

pipeline_final = Pipeline([
    ('preprocessor', preprocessor),
    ('model', best_model)
])

# Entraîner le modèle final sur l'ensemble des données d'entraînement
pipeline_final.fit(X_train, y_train)

# Faire des prédictions sur de nouvelles données
y_pred = pipeline_final.predict(X_test)

# Calculer la métrique d'évaluation finale (par exemple, le R2 score)
final_r2 = r2_score(y_test, y_pred)
final_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("Meilleurs hyperparamètres trouvés :", best_params)
print("R2 Score sur les données de test :", final_r2)
print(final_rmse)
# Out:
# [I 2023-07-26 15:02:13,889] A new study created in memory with name: no-name-ff96fe29-0344-4394-a531-e338158411ca
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:25,543] Trial 0 finished with value: 0.6652627871910658 and parameters: {'learning_rate': 0.03574712922600244, 'depth': 10, 'l2_leaf_reg': 0.8471801418819978, 'random_strength': 0.24810409748678125, 'border_count': 66}. Best is trial 0 with value: 0.6652627871910658.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:26,596] Trial 1 finished with value: 0.6655200188290804 and parameters: {'learning_rate': 0.01699897838270077, 'depth': 3, 'l2_leaf_reg': 2.9154431891537547, 'random_strength': 0.2537815508265665, 'border_count': 190}. Best is trial 1 with value: 0.6655200188290804.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:37,643] Trial 2 finished with value: 0.6122000700873467 and parameters: {'learning_rate': 0.010725209743171997, 'depth': 10, 'l2_leaf_reg': 2.1368329072358767, 'random_strength': 0.0070689749506246055, 'border_count': 72}. Best is trial 1 with value: 0.6655200188290804.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:39,192] Trial 3 finished with value: 0.6917304684753283 and parameters: {'learning_rate': 0.018659959624904916, 'depth': 5, 'l2_leaf_reg': 0.12561043700013558, 'random_strength': 0.05342937261279776, 'border_count': 97}. Best is trial 3 with value: 0.6917304684753283.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:40,434] Trial 4 finished with value: 0.67289860136913 and parameters: {'learning_rate': 0.08012737503998542, 'depth': 4, 'l2_leaf_reg': 0.01474275315991467, 'random_strength': 0.029204338471814112, 'border_count': 134}. Best is trial 3 with value: 0.6917304684753283.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:41,816] Trial 5 finished with value: 0.6495781511698254 and parameters: {'learning_rate': 0.14447746112718687, 'depth': 4, 'l2_leaf_reg': 0.11400863701127326, 'random_strength': 0.23423849847112907, 'border_count': 42}. Best is trial 3 with value: 0.6917304684753283.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:43,233] Trial 6 finished with value: 0.7014380924213459 and parameters: {'learning_rate': 0.07896186801026692, 'depth': 4, 'l2_leaf_reg': 0.0018205657658407262, 'random_strength': 6.245139574743075, 'border_count': 248}. Best is trial 6 with value: 0.7014380924213459.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:44,721] Trial 7 finished with value: 0.6978178216788805 and parameters: {'learning_rate': 0.1563510870813346, 'depth': 5, 'l2_leaf_reg': 0.002458603276328005, 'random_strength': 0.5456725485601477, 'border_count': 130}. Best is trial 6 with value: 0.7014380924213459.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:46,618] Trial 8 finished with value: 0.6967965202284763 and parameters: {'learning_rate': 0.015144860262751412, 'depth': 6, 'l2_leaf_reg': 0.0013726318898045872, 'random_strength': 4.337920697490942, 'border_count': 89}. Best is trial 6 with value: 0.7014380924213459.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:48,120] Trial 9 finished with value: 0.7285078964005609 and parameters: {'learning_rate': 0.09519754482692679, 'depth': 5, 'l2_leaf_reg': 0.12030178871154672, 'random_strength': 0.1537592023548176, 'border_count': 73}. Best is trial 9 with value: 0.7285078964005609.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:52,407] Trial 10 finished with value: 0.6606038982362856 and parameters: {'learning_rate': 0.2643008990658596, 'depth': 8, 'l2_leaf_reg': 7.553503645583182, 'random_strength': 0.001179906252315926, 'border_count': 178}. Best is trial 9 with value: 0.7285078964005609.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:55,525] Trial 11 finished with value: 0.7177451451034167 and parameters: {'learning_rate': 0.05604212881720619, 'depth': 7, 'l2_leaf_reg': 0.018118612189515562, 'random_strength': 7.771069696220199, 'border_count': 251}. Best is trial 9 with value: 0.7285078964005609.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:02:59,996] Trial 12 finished with value: 0.7008311355079572 and parameters: {'learning_rate': 0.052417803679489595, 'depth': 8, 'l2_leaf_reg': 0.024712286004906055, 'random_strength': 1.0486715032059042, 'border_count': 246}. Best is trial 9 with value: 0.7285078964005609.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:02,839] Trial 13 finished with value: 0.7071755478793842 and parameters: {'learning_rate': 0.036591532849893145, 'depth': 7, 'l2_leaf_reg': 0.3751747869442609, 'random_strength': 1.804792053905765, 'border_count': 197}. Best is trial 9 with value: 0.7285078964005609.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:05,761] Trial 14 finished with value: 0.7372617388535969 and parameters: {'learning_rate': 0.0920341405423421, 'depth': 7, 'l2_leaf_reg': 0.023441638371281635, 'random_strength': 2.4266520977290944, 'border_count': 222}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:08,110] Trial 15 finished with value: 0.7084737148765745 and parameters: {'learning_rate': 0.11405697859053684, 'depth': 6, 'l2_leaf_reg': 0.07185611224182761, 'random_strength': 2.443343311783758, 'border_count': 160}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:12,573] Trial 16 finished with value: 0.6331290510636672 and parameters: {'learning_rate': 0.2993501632241747, 'depth': 8, 'l2_leaf_reg': 0.006847206033969705, 'random_strength': 0.9864431342993051, 'border_count': 213}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:20,013] Trial 17 finished with value: 0.669026672440057 and parameters: {'learning_rate': 0.10971208780252577, 'depth': 9, 'l2_leaf_reg': 0.05025157400300556, 'random_strength': 0.09062439190798122, 'border_count': 112}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:21,835] Trial 18 finished with value: 0.7120964526001151 and parameters: {'learning_rate': 0.17317785036264008, 'depth': 5, 'l2_leaf_reg': 0.2812630139385361, 'random_strength': 9.144273895056907, 'border_count': 43}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:24,319] Trial 19 finished with value: 0.7058566857045185 and parameters: {'learning_rate': 0.21232652634065308, 'depth': 6, 'l2_leaf_reg': 0.006328422222466633, 'random_strength': 2.910832140731721, 'border_count': 216}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:27,737] Trial 20 finished with value: 0.7093329618741306 and parameters: {'learning_rate': 0.10354312854344702, 'depth': 7, 'l2_leaf_reg': 0.2305088641287187, 'random_strength': 0.546809440303392, 'border_count': 157}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:31,269] Trial 21 finished with value: 0.7131227412395962 and parameters: {'learning_rate': 0.06431187102508155, 'depth': 7, 'l2_leaf_reg': 0.033422963939891526, 'random_strength': 3.368520886067012, 'border_count': 229}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:34,789] Trial 22 finished with value: 0.707889422486071 and parameters: {'learning_rate': 0.050235396070110565, 'depth': 7, 'l2_leaf_reg': 0.01544578339869561, 'random_strength': 9.2211371453655, 'border_count': 254}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:42,349] Trial 23 finished with value: 0.6846656038567737 and parameters: {'learning_rate': 0.08105669029739657, 'depth': 9, 'l2_leaf_reg': 0.0647072715522729, 'random_strength': 9.927470719211845, 'border_count': 214}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:44,638] Trial 24 finished with value: 0.7142123396933894 and parameters: {'learning_rate': 0.12210518972731432, 'depth': 6, 'l2_leaf_reg': 0.02989754160111465, 'random_strength': 1.525706679534632, 'border_count': 235}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:46,313] Trial 25 finished with value: 0.7287435724349578 and parameters: {'learning_rate': 0.08970674762535574, 'depth': 5, 'l2_leaf_reg': 0.14789036886511958, 'random_strength': 4.100746524835617, 'border_count': 168}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:47,503] Trial 26 finished with value: 0.6327592237368247 and parameters: {'learning_rate': 0.1944683872367274, 'depth': 3, 'l2_leaf_reg': 0.14984938409587714, 'random_strength': 3.4334211760112963, 'border_count': 170}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:49,219] Trial 27 finished with value: 0.6947081471968239 and parameters: {'learning_rate': 0.09546442147691958, 'depth': 5, 'l2_leaf_reg': 0.04787583487804199, 'random_strength': 0.6131840949177577, 'border_count': 116}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:50,491] Trial 28 finished with value: 0.6720223763864659 and parameters: {'learning_rate': 0.14031664385908552, 'depth': 4, 'l2_leaf_reg': 0.6573275553188751, 'random_strength': 1.4229022620494527, 'border_count': 147}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:52,075] Trial 29 finished with value: 0.6934574386297923 and parameters: {'learning_rate': 0.06985777196688127, 'depth': 5, 'l2_leaf_reg': 0.08874343507393388, 'random_strength': 3.96816753187924, 'border_count': 57}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:54,074] Trial 30 finished with value: 0.6840958653041667 and parameters: {'learning_rate': 0.0984752542302435, 'depth': 6, 'l2_leaf_reg': 0.18680068998543242, 'random_strength': 0.188758534791809, 'border_count': 194}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:03:56,860] Trial 31 finished with value: 0.7243054075770557 and parameters: {'learning_rate': 0.058089463818962433, 'depth': 7, 'l2_leaf_reg': 0.07765185640461778, 'random_strength': 5.868660458178257, 'border_count': 232}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:04:01,099] Trial 32 finished with value: 0.7140701498967119 and parameters: {'learning_rate': 0.04168715628226667, 'depth': 8, 'l2_leaf_reg': 0.47954456638597176, 'random_strength': 4.794372231295409, 'border_count': 230}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:04:02,211] Trial 33 finished with value: 0.6945329623995693 and parameters: {'learning_rate': 0.06387370072942573, 'depth': 3, 'l2_leaf_reg': 0.20434587069222504, 'random_strength': 2.451683210778962, 'border_count': 181}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:04:09,621] Trial 34 finished with value: 0.683485766634637 and parameters: {'learning_rate': 0.09244753372502101, 'depth': 9, 'l2_leaf_reg': 1.2039420631708757, 'random_strength': 5.616431674714346, 'border_count': 202}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:04:11,130] Trial 35 finished with value: 0.7027565671420424 and parameters: {'learning_rate': 0.027299765899903395, 'depth': 5, 'l2_leaf_reg': 0.0907494546612116, 'random_strength': 0.367595490091138, 'border_count': 80}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:04:13,161] Trial 36 finished with value: 0.7104188922504278 and parameters: {'learning_rate': 0.13010902287106976, 'depth': 6, 'l2_leaf_reg': 0.14930683192620656, 'random_strength': 1.0387408296597258, 'border_count': 119}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# /tmp/ipykernel_10541/3184565285.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
# /tmp/ipykernel_10541/3184565285.py:33: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-3, 10.0),
# [I 2023-07-26 15:04:14,486] Trial 37 finished with value: 0.7081672370424777 and parameters: {'learning_rate': 0.08834508555998018, 'depth': 4, 'l2_leaf_reg': 0.36069238486149546, 'random_strength': 1.9814718458402154, 'border_count': 99}. Best is trial 14 with value: 0.7372617388535969.
# /tmp/ipykernel_10541/3184565285.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0
# 992:	learn: 19270.2052851	total: 3.1s	remaining: 21.9ms
# 993:	learn: 19240.4088346	total: 3.11s	remaining: 18.8ms
# 994:	learn: 19220.8832834	total: 3.11s	remaining: 15.6ms
# 995:	learn: 19199.9370501	total: 3.12s	remaining: 12.5ms
# 996:	learn: 19192.4013497	total: 3.12s	remaining: 9.39ms
# 997:	learn: 19180.5372070	total: 3.12s	remaining: 6.26ms
# 998:	learn: 19140.8298086	total: 3.13s	remaining: 3.13ms
# 999:	learn: 19121.1536749	total: 3.13s	remaining: 0us
# Meilleurs hyperparamètres trouvés : {'learning_rate': 0.0920341405423421, 'depth': 7, 'l2_leaf_reg': 0.023441638371281635, 'random_strength': 2.4266520977290944, 'border_count': 222}
# R2 Score sur les données de test : 0.6893320659621011
# 188317.28034495199

# %%
# Importer les bibliothèques nécessaires
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import r2_score, mean_squared_error
import optuna
from optuna.samplers import TPESampler
import pandas as pd
import numpy as np

# Définir les paramètres du préprocesseur
numerical_features = ['duration', 'press_eval', 'views', 'budget', 'proportion_stars_actors', 'proportion_stars_producers', 'proportion_stars_director', 'distributor_avg_frequency']
categorical_features = ['nationality', 'season', 'is_holiday']

numerical_transformer = StandardScaler()
categorical_transformer = OneHotEncoder()

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ],
    remainder="passthrough"
)

best_params = {
    'n_estimators': 100,
    'criterion': 'squared_error',
    'max_depth': 14,
    'min_samples_split': 3,
    'min_samples_leaf': 3,
    'max_features': None,
    'bootstrap': False
}
# Créer le modèle avec les meilleurs hyperparamètres
model = ExtraTreesRegressor(
    n_estimators=best_params['n_estimators'],
    criterion=best_params['criterion'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    max_features=best_params['max_features'],
    bootstrap=best_params['bootstrap']
)

pipe = Pipeline([
    ('preprocessor',preprocessor),
    ('model', model)
])

# %%
import mlflow

experiment_id = mlflow.set_experiment("cinema").experiment_id

run_name = "extratree_std_onehot"

with mlflow.start_run(experiment_id=experiment_id, run_name=run_name) as run:
    # Log the baseline model to MLflow
    pipe.fit(X_train, y_train)
    
    
    mlflow.sklearn.log_model(pipe, run_name)

    
    model_uri = mlflow.get_artifact_uri(run_name)

    # Log des paramètres
    mlflow.log_params({'n_estimators': 100,'criterion': 'squared_error','max_depth': 14, 'min_samples_split': 3,'min_samples_leaf': 3,
    'max_features': None,
    'bootstrap': False})
    
    
    # Log des Tags
    mlflow.set_tag("model","extra_tree")
    mlflow.set_tag("scaler","StandardScaler")
    mlflow.set_tag("encoder",'OneHotEncoder')
    mlflow.set_tag('df','sans_meteo')

    eval_data = X_test
    eval_data["label"] = y_test

    # Evaluate the logged model
    result = mlflow.evaluate(
        model_uri,
        eval_data,
        targets="label",
        model_type="regressor",
        evaluators=["default"],
   )
# Out:
# 2023/07/26 14:02:27 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# 2023/07/26 14:02:27 WARNING mlflow.models.evaluation.default_evaluator: Skip logging model explainability insights because the shap explainer None requires all feature values to be numeric, and each feature column must only contain scalar values.
