# %%
import pandas as pd

df = pd.read_csv('df_model_sans_meteo.csv')

# %%
from pycaret.regression import *

s = setup(df, target='box_office_first_week',session_id=123)
# Out:
# <style type="text/css">
# #T_12aa6_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_12aa6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12aa6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_12aa6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12aa6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12aa6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_12aa6_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_12aa6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12aa6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_12aa6_row1_col1" class="data row1 col1" >box_office_first_week</td>
#     </tr>
#     <tr>
#       <th id="T_12aa6_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
models = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           10:16:06
# Status     . . . . . . . . . . . . . . . . . .   Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_47570 th {
#   text-align: left;
# }
# ...

# %%
df_perf = pull(models)
display(df_perf)
# Out:
#                                     Model          MAE           MSE  \
# et                  Extra Trees Regressor   96637.5029  4.681353e+10
# catboost               CatBoost Regressor   96120.7999  4.781830e+10
# rf                Random Forest Regressor   99671.2381  5.004292e+10
# lightgbm  Light Gradient Boosting Machine   98824.1584  5.074197e+10
# gbr           Gradient Boosting Regressor  102507.1118  5.150261e+10
# ridge                    Ridge Regression  120065.3162  5.364131e+10
# lr                      Linear Regression  120114.1542  5.366931e+10
# lasso                    Lasso Regression  120111.2739  5.366718e+10
# llar         Lasso Least Angle Regression  120111.2591  5.366719e+10
# lar                Least Angle Regression  120593.6740  5.374920e+10
# xgboost         Extreme Gradient Boosting  102165.5480  5.295727e+10
# en                            Elastic Net  123840.9838  5.482959e+10
# br                         Bayesian Ridge  124567.0866  5.567620e+10
# ...

# %%
import pandas as pd

df = pd.read_csv('df_model.csv')

# %%
from pycaret.regression import *

s = setup(df, target='box_office_first_week',session_id=123)
# Out:
# <style type="text/css">
# #T_6ba8d_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6ba8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ba8d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6ba8d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ba8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ba8d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6ba8d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_6ba8d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ba8d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6ba8d_row1_col1" class="data row1 col1" >box_office_first_week</td>
#     </tr>
#     <tr>
#       <th id="T_6ba8d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
models = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           11:06:25
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
# <style type="text/css">
# #T_679e3 th {
#   text-align: left;
# }
# ...
